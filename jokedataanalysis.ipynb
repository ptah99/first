# %% [markdown]
# <a href="https://colab.research.google.com/github/ptah99/first/blob/main/jokedataanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno

# %%
df = pd.read_csv(r"https://github.com/Arifkhan21/MPII-Dataset-in-CSV/blob/master/mpii_dataset.csv?raw=true")
df.shape
# Out:
# (17372, 37)

# %%
df.describe()
# Out:
#        Unnamed: 0     r ankle_X  ...     l wrist_Y         Scale
# count     17372.0  17372.000000  ...  17372.000000  17372.000000
# mean          0.0    427.772680  ...    400.603845      3.605250
# std           0.0    403.733806  ...    182.811628      1.958356
# min           0.0     -1.000000  ...     -1.000000      0.544118
# 25%           0.0     -1.000000  ...    270.000000      2.170640
# 50%           0.0    390.000000  ...    374.000000      3.135194
# 75%           0.0    707.000000  ...    508.000000      4.554454
# max           0.0   1873.000000  ...   1087.000000     16.852803
#
# [8 rows x 34 columns]

# %%
df.head()
# Out:
#    Unnamed: 0           NAME  r ankle_X  ...     Scale  Activity  Category
# 0           0  015601864.jpg        620  ...  3.021046   curling    sports
# 1           0  015599452.jpg         -1  ...  5.641276   curling    sports
# 2           0  005808361.jpg        804  ...  4.718488   curling    sports
# 3           0  086617615.jpg        301  ...  2.681349   curling    sports
# 4           0  060111501.jpg        980  ...  3.806403   curling    sports
#
# [5 rows x 37 columns]

# %%
plt.figure(figsize=(14,8))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm', data=df)
plt.show()
